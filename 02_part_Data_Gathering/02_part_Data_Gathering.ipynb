# %% [markdown]
# # Part 2: Data Gathering

# %% [markdown]
# Once we retrieve our Vienna dataset, the very first step is to load it up and look at the raw rows and columns.

# %%
import pandas as pd

# %% [markdown]
# Our goal is to build a model that will suggest a price for a listing based on its features. So, we will be looking for the `price` column in our dataset, which will be our target variable. The other columns will be our features.

# %%
# Step 1: Read the full dataset with Pandas - the data is downloaded from: https://insideairbnb.com/get-the-data/#:~:text=Vienna%2C%20Vienna%2C%20Austria
vienna_listings = pd.read_csv("./data/vienna_listings.csv", encoding="utf-8")

# Step 2: Drop columns that are not relevant for our analysis
vienna_listings = vienna_listings.drop(
    columns=[
        "listing_url",
        "scrape_id",
        "calculated_host_listings_count",
        "calculated_host_listings_count_entire_homes",
        "calculated_host_listings_count_private_rooms",
        "calculated_host_listings_count_shared_rooms",
        "reviews_per_month",
        "minimum_nights",
        "maximum_nights",
        "minimum_minimum_nights",
        "maximum_minimum_nights",
        "minimum_maximum_nights",
        "maximum_maximum_nights",
        "minimum_nights_avg_ntm",
        "maximum_nights_avg_ntm",
        "calendar_updated",
        "has_availability",
        "availability_30",
        "availability_60",
        "availability_90",
        "availability_365",
        "calendar_last_scraped",
        "number_of_reviews",
        "number_of_reviews_ltm",
        "number_of_reviews_l30d",
        "availability_eoy",
        "number_of_reviews_ly",
        "estimated_occupancy_l365d",
        "estimated_revenue_l365d",
        "first_review",
        "last_review",
        "review_scores_rating",
        "review_scores_accuracy",
        "review_scores_cleanliness",
        "review_scores_checkin",
        "review_scores_communication",
        "review_scores_location",
        "review_scores_value",
        "license",
        "instant_bookable",
        "picture_url",
        "host_id",
        "host_url",
        "host_name",
        "host_has_profile_pic",
        "host_since",
        "host_location",
        "host_about",
        "host_response_time",
        "host_response_rate",
        "host_acceptance_rate",
        "host_is_superhost",
        "host_thumbnail_url",
        "host_picture_url",
        "host_neighbourhood",
        "host_listings_count",
        "host_total_listings_count",
        "host_verifications",
        "host_identity_verified",
        "last_scraped",
        "source",
        "id",
        "neighbourhood",
        "neighbourhood_group_cleansed",
    ],
)

# %%
# Step 3: Check the remaining columns
vienna_listings.columns
# Out:
# Index(['name', 'description', 'neighborhood_overview',
#        'neighbourhood_cleansed', 'latitude', 'longitude', 'property_type',
#        'room_type', 'accommodates', 'bathrooms', 'bathrooms_text', 'bedrooms',
#        'beds', 'amenities', 'price'],
#       dtype='str')

# %%
# Step 4: Show the dataset info
vienna_listings.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 14123 entries, 0 to 14122
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   name                    14123 non-null  str
#  1   description             13704 non-null  str
#  2   neighborhood_overview   6407 non-null   str
#  3   neighbourhood_cleansed  14123 non-null  str
#  4   latitude                14123 non-null  float64
#  5   longitude               14123 non-null  float64
#  6   property_type           14123 non-null  str
#  7   room_type               14123 non-null  str
#  8   accommodates            14123 non-null  int64
#  9   bathrooms               10329 non-null  float64
#  10  bathrooms_text          14117 non-null  str
#  11  bedrooms                12754 non-null  float64
#  12  beds                    10312 non-null  float64
#  13  amenities               14123 non-null  str
#  14  price                   10306 non-null  str
# ...

# %%
# Step 5: Show the first few rows of the dataset
vienna_listings.head()
# Out:
#                                                 name  \
# 0                     Near Palace Schönbrunn, Apt. 1
# 1  little studio- next to citycenter- wifi- nice ...
# 2                    Near Palace Schönbrunn - Apt. 4
# 3                     Near Palace Schönbrunn, Apt. 5
# 4                  Holiday Apartment "Modern Vienna"
#
#                                          description  \
# 0  Welcome to my Apt. 1!<br /><br />This is a 2be...
# 1  small studio in new renovated old house and ve...
# 2  Studio apartment for 4 persons:<br />- Bunk be...
# 3  Studio apartment for 4 persons:<br />- Bunk be...
# 4  Modern ambiance in a turn of the century house...
#
#                                neighborhood_overview neighbourhood_cleansed  \
# 0  The neighbourhood offers plenty of restaurants...   Rudolfsheim-Fnfhaus
# 1  The neighbourhood has a lot of very nice littl...           Leopoldstadt
# 2  The neighbourhood offers plenty of restaurants...   Rudolfsheim-Fnfhaus
# ...

# %%
# Step 6: Export the dataset to a new CSV file
vienna_listings.to_csv(
    "../03_part_Data_Cleaning_and_Feature_Engineering/data/vienna_listings_starting.csv",
    index=False,
)
